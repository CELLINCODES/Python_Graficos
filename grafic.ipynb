# %% [markdown]
# <a href="https://colab.research.google.com/github/CELLINCODES/Python_Graficos/blob/main/grafic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Gráfico **

# %%
import matplotlib.pyplot as plt

# %%
a = 'jan fev mar abr'.split()

# %%
b = [2000,4000,5000,4999]

# %%
plt.plot(a,b)
